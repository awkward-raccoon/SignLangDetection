# %% [markdown]
# # 1.) Installed and imported dependencies

# %%
# !pip install tensorflow==2.14.1 opencv-python mediapipe
# Out:
# Requirement already satisfied: tensorflow==2.14.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (2.14.1)
# Requirement already satisfied: opencv-python in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (4.9.0.80)
# Requirement already satisfied: mediapipe in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (0.8.10)
# Requirement already satisfied: tensorflow-intel==2.14.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.14.1) (2.14.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (3.3.0)
# Requirement already satisfied: packaging in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (3.20.3)
# Requirement already satisfied: setuptools in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (49.2.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (1.60.1)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.14.1->tensorflow==2.14.1) (2.14.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (23.2.0)
# Requirement already satisfied: matplotlib in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (3.8.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (4.9.0.80)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (6.1.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.1->tensorflow==2.14.1) (0.42.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->mediapipe) (3.17.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from markdown>=2.6.8->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (7.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.1->tensorflow==2.14.1) (3.2.2)

# %%
# !py --version
# Out:
# Python 3.9.0

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (1.4.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn) (3.2.0)

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (24.0)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install --upgrade keras
# Out:
# Requirement already satisfied: keras in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (2.14.0)
# Collecting keras
#   Using cached keras-3.0.4-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: absl-py in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from keras) (1.26.4)
# Collecting rich (from keras)
#   Using cached rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras)
#   Using cached namex-0.0.7-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: h5py in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from keras) (3.10.0)
# Collecting dm-tree (from keras)
#   Downloading dm_tree-0.1.8-cp39-cp39-win_amd64.whl (101 kB)
#      ---------------------------------------- 0.0/101.5 kB ? eta -:--:--
#      -------------------------------------- 101.5/101.5 kB 6.1 MB/s eta 0:00:00
# Collecting markdown-it-py>=2.2.0 (from rich->keras)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from rich->keras) (2.17.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras)
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached keras-3.0.4-py3-none-any.whl (1.0 MB)
# Using cached rich-13.7.0-py3-none-any.whl (240 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Installing collected packages: namex, dm-tree, mdurl, markdown-it-py, rich, keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
# Successfully installed dm-tree-0.1.8 keras-3.0.4 markdown-it-py-3.0.0 mdurl-0.1.2 namex-0.0.7 rich-13.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.14.1 requires keras<2.15,>=2.14.0, but you have keras 3.0.4 which is incompatible.

# %%
# !python -m pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from opencv-python) (1.26.4)

# %%
# !py -m pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from opencv-python) (1.26.4)

# %%
# !py -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !py -m pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (0.8.10)
# Requirement already satisfied: absl-py in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (23.2.0)
# Requirement already satisfied: matplotlib in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (3.8.2)
# Requirement already satisfied: numpy in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (4.9.0.80)
# Requirement already satisfied: protobuf>=3.11.4 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->mediapipe) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)

# %%
# !pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (0.8.8.1)
# Requirement already satisfied: absl-py in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (23.2.0)
# Requirement already satisfied: matplotlib in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (3.8.2)
# Requirement already satisfied: numpy in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (4.9.0.80)
# Requirement already satisfied: protobuf>=3.11.4 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: six in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (1.16.0)
# Requirement already satisfied: wheel in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from mediapipe) (0.42.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->mediapipe) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ajbir\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->mediapipe) (3.17.0)

# %% [markdown]
# # 2.) Keypoints using MP Holistic

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
# For accessing cam

# cap = cv2.VideoCapture(0)
# # Set mediapipe model 
# # with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
# while cap.isOpened():

#     # Read feed
#     ret, frame = cap.read()

#     # # Make detections
#     # image, results = mediapipe_detection(frame, holistic)
#     # print(results)
    
#     # Draw landmarks
#     # draw_styled_landmarks(image, results)

#     # Show to screen
#     cv2.imshow('OpenCV Feed', frame)

#     # Break gracefully
#     if cv2.waitKey(10) & 0xFF == ord('q'):
#         break
# cap.release()
# cv2.destroyAllWindows()

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3.) Extract Keypoint Values

# %%
# len(results.left_hand_landmarks.landmark)

# %%
# pose = []
# for res in results.pose_landmarks.landmark:
#     test = np.array([res.x, res.y, res.z, res.visibility])
#     pose.append(test)

# %%
# pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
# face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
# lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
# rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
# face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.47225562,  0.38717872, -1.80894125, ...,  0.        ,
#         0.        ,  0.        ])

# %%
len(result_test)
# Out:
# 1662

# %% [markdown]
# # 4. Setup Folders for Collection
